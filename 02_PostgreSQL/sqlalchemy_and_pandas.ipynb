# %% [markdown]
# ### Appendix

# %% [markdown]
# ##### SqlAlchemy

# %%
# !pip install sqlalchemy
# Out:
# ...
#   Obtaining dependency information for sqlalchemy from https://files.pythonhosted.org/packages/83/34/e760f4e78b2aeb04a74ae7338f9c215570a256755ab0026336037ec8df75/SQLAlchemy-2.0.29-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for greenlet!=0.4.17 from https://files.pythonhosted.org/packages/47/79/26d54d7d700ef65b689fc2665a40846d13e834da0486674a8d4f0f371a47/greenlet-3.0.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached greenlet-3.0.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 26.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 22.2 MB/s eta 0:00:00
# Using cached greenlet-3.0.3-cp311-cp311-win_amd64.whl (292 kB)
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# ...

# %%
from sqlalchemy import create_engine, text


engine = create_engine("postgresql+psycopg2://postgres:postgres@127.0.0.1:5432/classicmodels")

stmt = text("SELECT productname FROM products WHERE productline='Motorcycles';")

with engine.connect() as cnx:
    result = cnx.execute(stmt)

    for row in result:
        print(row)
# Out:
# ('1969 Harley Davidson Ultimate Chopper',)
# ('1996 Moto Guzzi 1100i',)
# ('2003 Harley-Davidson Eagle Drag Bike',)
# ('2002 Suzuki XREO',)
# ('1936 Harley Davidson El Knucklehead',)
# ('1957 Vespa GS150',)
# ('1997 BMW R 1100 S',)
# ('1960 BSA Gold Star DBD34',)
# ('1982 Ducati 900 Monster',)
# ('1997 BMW F650 ST',)
# ('1982 Ducati 996 R',)
# ('1974 Ducati 350 Mk3 Desmo',)
# ('2002 Yamaha YZR M1',)

# %%
from sqlalchemy import create_engine, text, Table, MetaData, select

metadata_obj = MetaData()
engine = create_engine("postgresql+psycopg2://postgres:postgres@127.0.0.1:5432/classicmodels")

Product = Table(
    'products',
    metadata_obj,
    autoload_with=engine
)

stmt = select(Product).where(Product.c.productline=='Motorcycles')

with engine.connect() as cnx:
    result = cnx.execute(stmt)

    for row in result:
        print(row.productname)

# !pip install pandas
# Out:
# 1969 Harley Davidson Ultimate Chopper
# 1996 Moto Guzzi 1100i
# 2003 Harley-Davidson Eagle Drag Bike
# 2002 Suzuki XREO
# 1936 Harley Davidson El Knucklehead
# 1957 Vespa GS150
# 1997 BMW R 1100 S
# 1960 BSA Gold Star DBD34
# 1982 Ducati 900 Monster
# 1997 BMW F650 ST
# 1982 Ducati 996 R
# 1974 Ducati 350 Mk3 Desmo
# 2002 Yamaha YZR M1
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#        quantityinstock   buyprice        msrp
# count        13.000000  13.000000   13.000000
# mean       5338.538462  50.685385   97.178462
# std        3394.898001  19.975823   41.020683
# min          15.000000  24.140000   40.230000
# 25%        3341.000000  34.170000   69.260000
# 50%        6625.000000  48.810000   95.700000
# 75%        7689.000000  66.270000  112.700000
# max        9997.000000  91.020000  193.660000

# %%
# !pip install pandas

# %%
import pandas as pd

connection_string = "postgresql+psycopg2://postgres:postgres@127.0.0.1:5432/classicmodels"
stmt = "SELECT * FROM products WHERE productline='Motorcycles';"

df = pd.read_sql_query(stmt, connection_string)
df
# Out:
#    productcode                            productname  productline  \
# 0     S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 1     S10_2016                  1996 Moto Guzzi 1100i  Motorcycles
# 2     S10_4698   2003 Harley-Davidson Eagle Drag Bike  Motorcycles
# 3     S12_2823                       2002 Suzuki XREO  Motorcycles
# 4     S18_2625    1936 Harley Davidson El Knucklehead  Motorcycles
# 5     S18_3782                       1957 Vespa GS150  Motorcycles
# 6     S24_1578                      1997 BMW R 1100 S  Motorcycles
# 7     S24_2000               1960 BSA Gold Star DBD34  Motorcycles
# 8     S24_2360                1982 Ducati 900 Monster  Motorcycles
# 9     S32_1374                       1997 BMW F650 ST  Motorcycles
# 10    S32_2206                      1982 Ducati 996 R  Motorcycles
# 11    S32_4485              1974 Ducati 350 Mk3 Desmo  Motorcycles
# 12    S50_4713                     2002 Yamaha YZR M1  Motorcycles
#
# ...

# %%
df.describe()
# Out:
#        quantityinstock   buyprice        msrp
# count        13.000000  13.000000   13.000000
# mean       5338.538462  50.685385   97.178462
# std        3394.898001  19.975823   41.020683
# min          15.000000  24.140000   40.230000
# 25%        3341.000000  34.170000   69.260000
# 50%        6625.000000  48.810000   95.700000
# 75%        7689.000000  66.270000  112.700000
# max        9997.000000  91.020000  193.660000
